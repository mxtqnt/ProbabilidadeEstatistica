# %%
import matplotlib.pyplot as plt 
import numpy as np 
import pandas as pd
import seaborn as sns 

base_de_dados = pd.read_excel('data/dados_estudantes.xlsx')

print(base_de_dados)

color = (0.2, # redness
         0.4, # greenness
         0.2, # blueness
         0.6 # transparency
         )
# Out:
#     Id Turma Sexo  Idade   Alt  Peso  Filhos Fuma Toler  Exerc  Cine OpCine  \
# 0    1     A    F     17  1.60  60.5       2  NAO     P      0     1      B
# 1    2     A    F     18  1.69  55.0       1  NAO     M      0     1      B
# 2    3     A    M     18  1.85  72.8       2  NAO     P      5     2      M
# 3    4     A    M     25  1.85  80.9       2  NAO     P      5     2      B
# 4    5     A    F     19  1.58  55.0       1  NAO     M      2     2      B
# 5    6     A    M     19  1.76  60.0       3  NAO     M      2     1      B
# 6    7     A    F     20  1.60  58.0       1  NAO     P      3     1      B
# 7    8     A    F     18  1.64  47.0       1  SIM     I      2     2      M
# 8    9     A    F     18  1.62  57.8       3  NAO     M      3     3      M
# 9   10     A    F     17  1.64  58.0       2  NAO     M      2     2      M
# 10  11     A    F     18  1.72  70.0       1  SIM     I     10     2      B
# ...

# %%
data = base_de_dados['Turma'].value_counts().reset_index()

print(data)

labels = data['Turma']
tamanhos = data['count']

plt.pie(tamanhos, labels=labels, autopct='%1.1f%%', startangle=140, colors=sns.color_palette('Pastel1'))
plt.title('Alunos por turma')
plt.axis('equal')
plt.show()
# Out:
#   Turma  count
# 0     A     26
# 1     B     24

# %%
data = base_de_dados['Sexo'].value_counts().reset_index()

print(data)

labels = data['Sexo']
tamanhos = data['count']

plt.pie(tamanhos, labels=labels, autopct='%1.1f%%', startangle=140, colors=sns.color_palette('Pastel1'))
plt.title('Genero de Alunos')
plt.axis('equal')
plt.show()
# Out:
#   Sexo  count
# 0    F     36
# 1    M     12
# 2   NI      2

# %%
data = base_de_dados['Idade'].value_counts().reset_index()

print(data)

objects = data['Idade']
performance = data['count']

y_pos = np.arange(len(objects))

plt.bar(y_pos, performance, align='center', alpha=0.5, color=color)
plt.xticks(y_pos, objects)
plt.ylabel('Recorrencia')
plt.title('Idade Alunos')

plt.show()
# Out:
#    Idade  count
# 0     18     22
# 1     17      9
# 2     19      7
# 3     20      4
# 4     21      3
# 5     25      2
# 6     23      2
# 7     24      1

# %%
intervalos = pd.cut(base_de_dados['Alt'], bins=5)
data = intervalos.value_counts().reset_index()

print(data)

objects = data['Alt']
performance = data['count']

y_pos = np.arange(len(objects))

plt.bar(y_pos, performance, align='center', alpha=0.5, color=color)
plt.xticks(y_pos, objects)
plt.ylabel('Usage')
plt.title('Altura Alunos')

plt.show()
# Out:
#             Alt  count
# 0  (1.61, 1.69]     16
# 1  (1.53, 1.61]     13
# 2  (1.69, 1.77]     12
# 3  (1.77, 1.85]      8
# 4  (1.45, 1.53]      1

# %%
intervalos = pd.cut(base_de_dados['Peso'], bins=5)
data = intervalos.value_counts().reset_index()

print(data)

objects = data['Peso']
performance = data['count']

y_pos = np.arange(len(objects))

plt.bar(y_pos, performance, align='center', alpha=0.5, color=color)
plt.xticks(y_pos, objects)
plt.ylabel('Usage')
plt.title('Peso dos Alunos')

plt.show()
# Out:
#              Peso  count
# 0    (54.2, 64.4]     21
# 1  (43.949, 54.2]     15
# 2    (64.4, 74.6]      7
# 3    (84.8, 95.0]      4
# 4    (74.6, 84.8]      3

# %%
data = base_de_dados['Filhos'].value_counts().reset_index()

print(data)

labels = data['Filhos']
tamanhos = data['count']

plt.pie(tamanhos, labels=labels, autopct='%1.1f%%', startangle=140, colors=sns.color_palette('Pastel1'))
plt.title('Quantidade de Filhos de Alunos')
plt.axis('equal')
plt.show()
# Out:
#    Filhos  count
# 0       1     28
# 1       2     14
# 2       3      6
# 3       4      1
# 4       7      1

# %%
data = base_de_dados['Fuma'].value_counts().reset_index()

print(data)

labels = data['Fuma']
tamanhos = data['count']

plt.pie(tamanhos, labels=labels, autopct='%1.1f%%', startangle=140, colors=sns.color_palette('Pastel1'))
plt.title('Alunos Fumantes ou Não')
plt.axis('equal')
plt.show()
# Out:
#   Fuma  count
# 0  NAO     44
# 1  SIM      6

# %%
data = base_de_dados['Toler'].value_counts().reset_index()

print(data)
print('(I) Indiferente, (P) incomoda pouco e (M) incomoda muito') 

labels = data['Toler']
tamanhos = data['count']

plt.pie(tamanhos, labels=labels, autopct='%1.1f%%', startangle=140, colors=sns.color_palette('Pastel1'))
plt.title('Tolerância dos Alunos ao Cigarro')

plt.axis('equal')
plt.show()
# Out:
#   Toler  count
# 0     P     21
# 1     M     19
# 2     I     10
# (I) Indiferente, (P) incomoda pouco e (M) incomoda muito

# %%
intervalos = pd.cut(base_de_dados['Exerc'], bins=5)
data = intervalos.value_counts().reset_index()

print(data)

objects = data['Exerc']
performance = data['count']

y_pos = np.arange(len(objects))

plt.bar(y_pos, performance, align='center', alpha=0.5, color=color)
plt.xticks(y_pos, objects)
plt.ylabel('Usage')
plt.title('Horas de atividades física, por semana')

plt.show()
# Out:
#           Exerc  count
# 0  (-0.01, 2.0]     19
# 1    (4.0, 6.0]     11
# 2    (2.0, 4.0]     10
# 3    (6.0, 8.0]      8
# 4   (8.0, 10.0]      2

# %%
intervalos = pd.cut(base_de_dados['Cine'], bins=5)
data = intervalos.value_counts().reset_index()

print(data)

objects = data['Cine']
performance = data['count']

y_pos = np.arange(len(objects))

plt.bar(y_pos, performance, align='center', alpha=0.5, color=color)
plt.xticks(y_pos, objects)
plt.ylabel('Usage')
plt.title('Número de vezes que vai ao cinema por semana')

plt.show()
# Out:
#             Cine  count
# 0  (-0.005, 1.0]     24
# 1     (1.0, 2.0]     18
# 2     (3.0, 4.0]      4
# 3     (2.0, 3.0]      3
# 4     (4.0, 5.0]      1

# %%
data = base_de_dados['OpCine'].value_counts().reset_index()

print(data)
print('(B) regular e boa e (M) muito boa') 

labels = data['OpCine']
tamanhos = data['count']

plt.pie(tamanhos, labels=labels, autopct='%1.1f%%', startangle=140, colors=sns.color_palette('Pastel1'))
plt.title('Opinião a respeito das salas de cinema na cidade')

plt.axis('equal')
plt.show()
# Out:
#   OpCine  count
# 0      B     32
# 1      M     18
# (B) regular e boa e (M) muito boa

# %%
intervalos = pd.cut(base_de_dados['TV'], bins=5)
data = intervalos.value_counts().reset_index()

print(data)

objects = data['TV']
performance = data['count']

y_pos = np.arange(len(objects))

plt.bar(y_pos, performance, align='center', alpha=0.5, color=color)
plt.xticks(y_pos, objects)
plt.ylabel('Usage')
plt.title('Horas gastas assistindo TV, por semana')

plt.show()
# Out:
#              TV  count
# 0   (6.0, 12.0]     20
# 1  (-0.03, 6.0]     15
# 2  (12.0, 18.0]      8
# 3  (24.0, 30.0]      4
# 4  (18.0, 24.0]      3

# %%
data = base_de_dados['OpTV'].value_counts().reset_index()

print(data)
print('(R) ruim, (M) média, (B) boa e (N) não sabe') 

labels = data['OpTV']
tamanhos = data['count']

plt.pie(tamanhos, labels=labels, autopct='%1.1f%%', startangle=140, colors=sns.color_palette('Pastel1'))
plt.title('Oopinião a respeito da qualidade da programação na TV')

plt.axis('equal')
plt.show()
# Out:
#   OpTV  count
# 0    R     39
# 1    N      7
# 2    B      3
# 3    M      1
# (R) ruim, (M) média, (B) boa e (N) não sabe

# %%
data = base_de_dados[['Alt', 'Peso']]

print(data)
print('(B) regular e boa e (M) muito boa') 

x = np.array(data['Alt']) 
y = np.array(data['Peso'])

plt.scatter(x, y, color=color)
plt.title('Altura x Peso')
plt.show()
# Out:
#      Alt  Peso
# 0   1.60  60.5
# 1   1.69  55.0
# 2   1.85  72.8
# 3   1.85  80.9
# 4   1.58  55.0
# 5   1.76  60.0
# 6   1.60  58.0
# 7   1.64  47.0
# 8   1.62  57.8
# 9   1.64  58.0
# 10  1.72  70.0
# 11  1.66  54.0
# 12  1.70  58.0
# 13  1.78  68.5
# 14  1.65  63.5
# 15  1.63  47.4
# 16  1.82  66.0
# 17  1.80  85.2
# 18  1.60  54.5
# 19  1.68  52.5
# 20  1.70  60.0
# 21  1.65  58.5
# 22  1.57  49.2
# 23  1.55  48.0
# 24  1.69  51.6
# 25  1.54  57.0
# 26  1.62  63.0
# 27  1.62  52.0
# 28  1.57  49.0
# 29  1.65  59.0
# 30  1.61  52.0
# 31  1.71  73.0
# 32  1.65  56.0
# 33  1.67  58.0
# 34  1.73  87.0
# 35  1.60  47.0
# 36  1.70  95.0
# 37  1.85  84.0
# 38  1.70  60.0
# 39  1.73  73.0
# 40  1.70  55.0
# 41  1.45  44.0
# 42  1.76  75.0
# 43  1.68  55.0
# 44  1.55  49.0
# 45  1.70  50.0
# 46  1.55  54.5
# 47  1.60  50.0
# 48  1.80  71.0
# 49  1.83  86.0
# (B) regular e boa e (M) muito boa

# %%
data = base_de_dados[['Idade', 'Alt']]

print(data)
print('(B) regular e boa e (M) muito boa') 

x = np.array(data['Idade']) 
y = np.array(data['Alt'])

plt.scatter(x, y, color=color)
plt.title('Idade x Altura')
plt.show()
# Out:
#     Idade   Alt
# 0      17  1.60
# 1      18  1.69
# 2      18  1.85
# 3      25  1.85
# 4      19  1.58
# 5      19  1.76
# 6      20  1.60
# 7      18  1.64
# 8      18  1.62
# 9      17  1.64
# 10     18  1.72
# 11     18  1.66
# 12     21  1.70
# 13     19  1.78
# 14     18  1.65
# 15     19  1.63
# 16     17  1.82
# 17     18  1.80
# 18     20  1.60
# 19     18  1.68
# 20     21  1.70
# 21     18  1.65
# 22     18  1.57
# 23     20  1.55
# 24     20  1.69
# 25     19  1.54
# 26     23  1.62
# 27     18  1.62
# 28     18  1.57
# 29     25  1.65
# 30     18  1.61
# 31     17  1.71
# 32     17  1.65
# 33     17  1.67
# 34     18  1.73
# 35     18  1.60
# 36     17  1.70
# 37     21  1.85
# 38     18  1.70
# 39     18  1.73
# 40     17  1.70
# 41     23  1.45
# 42     24  1.76
# 43     18  1.68
# 44     18  1.55
# 45     19  1.70
# 46     19  1.55
# 47     18  1.60
# 48     17  1.80
# 49     18  1.83
# (B) regular e boa e (M) muito boa

# %%
data = base_de_dados[['Fuma', 'Sexo']]

# Contagem de ocorrências para cada combinação de Fuma e Sexo
count_data = data.groupby(['Fuma', 'Sexo']).size().unstack()
# Plotando o gráfico de barras empilhadas
count_data.plot(kind='bar', stacked=False, color=sns.color_palette('Pastel1'))

plt.title('Relação entre Fumante e Gênero')
plt.xlabel('Fuma')
plt.ylabel('Contagem')
plt.legend(title='Sexo')

plt.show()

# %%
data = base_de_dados[['Fuma', 'Toler']]

# Contagem de ocorrências para cada combinação de Fuma e Toler
count_data = data.groupby(['Fuma', 'Toler']).size().unstack()

# Definindo cores
colors = sns.color_palette('Pastel1')

# Plotando o gráfico de barras empilhadas
ax = count_data.plot(kind='bar', stacked=False, color=colors)

# Editando legendas
legend_labels = ['Indiferente', 'Pouco Incômodo', 'Muito Incômodo']
ax.legend(legend_labels, title='Tipo de Tolerância')

plt.title('Relação entre Tolerância e Fumante')
plt.xlabel('Fuma?')
plt.ylabel('Contagem')

plt.show()
