# %%
import matplotlib.pyplot as plt 
import numpy as np 
import pandas as pd
import seaborn as sns 

base_de_dados = pd.read_excel('data/pobreza_brasil.xlsx')

base_de_dados
# Out:
#           Genero  Idade  Escolaridade  Trabalho Reg_metrop         Cor  \
# 0      Masculino     59             5         8     Metrop  Nao Branco
# 1      Masculino     21             5         8     Metrop      Branco
# 2      Masculino     59             2         9     Metrop  Nao Branco
# 3       Feminino     58             5         8     Metrop  Nao Branco
# 4       Feminino     56             2         9     Metrop  Nao Branco
# ...          ...    ...           ...       ...        ...         ...
# 20747   Feminino     46             4        11     Metrop  Nao Branco
# 20748  Masculino     47             1         3     Metrop      Branco
# 20749  Masculino     41             7         4     Metrop  Nao Branco
# 20750   Feminino     42             7         7     Metrop  Nao Branco
# 20751  Masculino     49             5         8     Metrop  Nao Branco
#
#       Reg_Urbano Cart_assinada Pobreza
# 0         Urbano        Outros     Nao
# ...

# %%
# Pizza Pobreza

data = base_de_dados['Pobreza'].value_counts().reset_index()

labels = data['Pobreza']
tamanhos = data['count']

plt.pie(tamanhos, labels=labels, autopct='%1.1f%%', startangle=140, colors=sns.color_palette('Pastel1'))
plt.title('Relação Pobreza')
plt.axis('equal')
plt.show()

# %%
# Colunas Pobreza x Genero

data = base_de_dados['Genero'].value_counts().reset_index()

print(data)

labels = data['Pobreza']
tamanhos = data['count']

 plt.pie(tamanhos, labels=labels, autopct='%1.1f%%', startangle=140, colors=sns.color_palette('Pastel1'))
plt.title('Relação Pobreza x Genero')
plt.axis('equal')
plt.show()
# Out:
#       Genero  count
# 0  Masculino  12585
# 1   Feminino   8167
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Ana Carolina\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Pobreza'
#
# The above exception was the direct cause of the following exception:
#
# ...
