# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_excel('data/pobreza_brasil.xlsx')
df.head()
color = (0.2, # redness
         0.4, # greenness
         0.2, # blueness
         0.6 # transparency
         )

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20752 entries, 0 to 20751
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Genero         20752 non-null  object
#  1   Idade          20752 non-null  int64
#  2   Escolaridade   20752 non-null  int64
#  3   Trabalho       20752 non-null  int64
#  4   Reg_metrop     20752 non-null  object
#  5   Cor            20752 non-null  object
#  6   Reg_Urbano     20752 non-null  object
#  7   Cart_assinada  20752 non-null  object
#  8   Pobreza        20752 non-null  object
# dtypes: int64(3), object(6)
# memory usage: 1.4+ MB

# %%
df.describe()
# Out:
#               Idade  Escolaridade      Trabalho
# count  20752.000000  20752.000000  20752.000000
# mean      40.861845      4.533009      5.342907
# std       12.598501      1.891997      3.174946
# min       14.000000      1.000000      1.000000
# 25%       31.000000      2.000000      2.000000
# 50%       40.000000      5.000000      4.000000
# 75%       50.000000      6.000000      8.000000
# max       91.000000      7.000000     12.000000

# %%
values = df['Genero'].value_counts(normalize=True).reset_index()

print(values)
plt.pie(values, labels=(values.index), autopct='%1.1f%%', startangle=140, colors=sns.color_palette('Pastel1'))
plt.title('Divisão dos dados por gênero')


# labels = df['OpTV']
# tamanhos = df['count']

plt.show()
# Out:
#       Genero  proportion
# 0  Masculino    0.606448
# 1   Feminino    0.393552
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_1133/1968022315.py in ?()
#       1 values = df['Genero'].value_counts(normalize=True).reset_index()
#       2
#       3 print(values)
# ----> 4 plt.pie(values, labels=(values.index), autopct='%1.1f%%', startangle=140, colors=sns.color_palette('Pastel1'))
#       5 plt.title('Divisão dos dados por gênero')
#       6
#       7
#
# ~/projects/ProbabilidadeEstatistica/.venv/lib/python3.11/site-packages/matplotlib/pyplot.py in ?(x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, normalize, hatch, data)
#    3554     normalize: bool = True,
#    3555     hatch: str | Sequence[str] | None = None,
#    3556     data=None,
# ...

# %%
values = df['Idade'].value_counts()
plt.bar(x=(values.index), height=values, align='center', alpha=0.5, color=color)
plt.title('Divisão dos dados por idade')
plt.show()

# %%
values = df['Escolaridade'].value_counts()
plt.bar(x=(values.index), height=values, align='center', alpha=0.5, color=color)
plt.title('Divisâo dos dados por escolaridade')
plt.show()

# %%
values = df['Trabalho'].value_counts()
plt.bar(x=values.index, height=values, align='center', alpha=0.5, color=color)
plt.title('categorias de trabalho')
plt.show()

# %%
values = df['Reg_metrop'].value_counts()
plt.pie(values, labels=(values.index), autopct='%1.1f%%', startangle=140, colors=sns.color_palette('Pastel1'))
plt.title('Divisão dos dados por região')
plt.show()

# %%
values = df['Cor'].value_counts()
plt.pie(values, labels=(values.index), autopct='%1.1f%%', startangle=140, colors=sns.color_palette('Pastel1'))
plt.title('Divisão dos dados por cor de pele')
plt.show()

# %%
values = df['Cart_assinada'].value_counts()

plt.bar(x=values.index, height=values, align='center', alpha=0.5, color=color)
plt.title('Divisão dos dados por carteira de trabalho assinada')
plt.show()

# %%
values = df['Pobreza'].value_counts()
plt.pie(values, labels=(values.index), autopct='%1.1f%%', startangle=140, colors=sns.color_palette('Pastel1'))
plt.title('Divisão dos dados por pobreza')
plt.show()

# %%
# Criando uma tabela de frequências cruzadas
cross_tab = pd.crosstab(df['Trabalho'], df['Genero'])
display(cross_tab)
# Plotando o gráfico de barras agrupadas
cross_tab.plot(kind='barh', stacked=False,color=sns.color_palette('Pastel1'))

plt.title('Tipos de Trabalho por Gênero')
plt.xlabel('Quantidade de Pessoas')
plt.ylabel('Tipo de Trabalho')

plt.show()
# Out:
# Genero    Feminino  Masculino
# Trabalho
# 1              296       2591
# 2              812       1653
# 3               52       1319
# 4             1475       2297
# 5               69        823
# 6              470        414
# 7              788       1269
# 8              559        874
# 9             2095        738
# 10             538        467
# 11            1012        140
# 12               1          0

# %%
# Criando uma tabela de frequências cruzadas
cross_tab = pd.crosstab(df['Escolaridade'], df['Cor'])
display(cross_tab)
# Plotando o gráfico de barras empilhadas
cross_tab.plot(kind='bar', stacked=True,color= sns.color_palette('Pastel1'))

plt.title('Escolaridade por Cor')
plt.xlabel('Escolaridade')
plt.ylabel('Quantidade de Pessoas')


plt.show()
# Out:
# Cor           Branco  Nao Branco
# Escolaridade
# 1                 94         305
# 2               1842        3071
# 3                679         904
# 4                410         735
# 5               2915        3729
# 6                616         565
# 7               2874        2013

# %%
# Criando uma tabela de frequências cruzadas
cross_tab = pd.crosstab(df['Pobreza'], df['Genero'])

display(cross_tab)

# Plotando o gráfico de barras agrupadas
cross_tab.plot(kind='bar', stacked=False,color=sns.color_palette('Pastel1'))

plt.title('Pobreza por Gênero')
plt.xlabel('Gênero')
plt.ylabel('Quantidade de Pessoas')

plt.show()
# Out:
# Genero   Feminino  Masculino
# Pobreza
# Nao          6651       9433
# Pobreza      1516       3152

# %%
# Criação de tabelas cruzadas
cross_tab1 = pd.crosstab(df['Reg_metrop'], df['Pobreza'])
cross_tab2 = pd.crosstab(df['Reg_Urbano'], df['Pobreza'])

fig, ax = plt.subplots(1, 2, figsize=(12, 6))

# Gráfico de barras empilhadas para 'Reg_metrop' e 'Pobreza'
cross_tab1.plot(kind='bar', stacked=True, ax=ax[0], color=sns.color_palette('Pastel1'))
ax[0].set_title('Relação entre Região Metropolitana e Pobreza')
ax[0].set_xlabel('Região Metropolitana')
ax[0].set_ylabel('Contagem')

# Gráfico de barras empilhadas para 'Reg_Urbano' e 'Pobreza'
cross_tab2.plot(kind='bar', stacked=True, ax=ax[1], color=sns.color_palette('Pastel1'))
ax[1].set_title('Relação entre Região Urbana e Pobreza')
ax[1].set_xlabel('Região Urbana')
ax[1].set_ylabel('Contagem')

display(cross_tab1)
display(cross_tab2)

plt.tight_layout()
plt.show()
# Out:
# Pobreza      Nao  Pobreza
# Reg_metrop
# Metrop      6427     1262
# Nao_Metrop  9657     3406
# Pobreza       Nao  Pobreza
# Reg_Urbano
# Rural        2553     1874
# Urbano      13531     2794

# %%
# Criando uma tabela de frequências cruzadas
cross_tab = pd.crosstab(df['Trabalho'], df['Escolaridade'])

# Plotando o gráfico de barras agrupadas
cross_tab.plot(kind='barh', stacked=False,color=sns.color_palette('Pastel1'))
display(cross_tab)
plt.title('Tipos de Trabalho e Escolaridade')
plt.xlabel('Quantidade de Pessoas')
plt.ylabel('Tipo de Trabalho')

plt.show()
# Out:
# Escolaridade    1     2    3    4     5    6     7
# Trabalho
# 1             205  1618  283  154   510   33    84
# 2              30   550  239  169   962  135   380
# 3              24   573  166  116   361   31   100
# 4              34   650  308  288  1639  274   579
# 5               7   234   92   52   373   40    94
# 6              21   234   98   65   328   49    89
# 7              17   166   72   69   593  212   928
# 8              10   114   44   30   445  130   660
# 9               4    88   57   38   701  188  1757
# 10              8   139   75   74   437   75   197
# 11             39   547  149   90   295   14    18
# 12              0     0    0    0     0    0     1
